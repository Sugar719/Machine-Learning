# %% [markdown]
# # Random noise 50 samples

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib as mpl
# %matplotlib inline

np.random.seed(0)
a_train = np.random.random((1, 50)) - 0.5
x_train = np.linspace(0, 1, 50)
y_train = np.sin(2 * np.pi * x_train)
y_train = y_train - a_train * 2
y_train = y_train[0]

a_test = np.random.random((1, 10)) - 0.5
x_test = np.linspace(0.7, 1.0, 10)
y_test = np.sin(2 * np.pi * x_test)
y_test = y_test - a_test * 2
y_test = y_test[0]

x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

def degree_3(x_train,y_train,x_test,y_test):

    quadratic_featurizer = PolynomialFeatures(degree=3)
    x_train_quadratic = quadratic_featurizer.fit_transform(x_train)
    model2 = LinearRegression()
    model2 = model2.fit(x_train_quadratic, y_train)

    xx = np.linspace(0, 1, 1000)
    xx_quadratic = quadratic_featurizer.transform(xx.reshape(xx.shape[0], 1))
    yy_predict = model2.predict(xx_quadratic)
    plt.plot(xx, yy_predict, 'r-')

    x_pred2 = quadratic_featurizer.transform(x_train.reshape(x_train.shape[0], 1))
    y_pred2 = model2.predict(x_pred2)
    model2_train_mean_sqaured_error = mean_squared_error(y_train, y_pred2)

    x_pred1 = quadratic_featurizer.transform(x_test.reshape(x_test.shape[0], 1))
    y_pred1 = model2.predict(x_pred1)
    model2_test_mean_sqaured_error = mean_squared_error(y_test, y_pred1)
    x_test_quadratic = quadratic_featurizer.transform(x_test)
    print('%d次多项式回归：  ' % 3)
    print('训练集均方根误差：%f' % model2_train_mean_sqaured_error)
    print('测试集均方根误差：%f' % model2_test_mean_sqaured_error)
    plt.scatter(x_train, y_train)

    x = np.linspace(0, 1, 1000)
    y = np.sin(2 * np.pi * x)
    plt.plot(x, y)
    plt.title(r'$y=sin(2{\pi}x)$')  
    plt.xlabel('x') 
    plt.ylabel('y')  
    plt.ylim(-1.2,1.2)
    plt.grid(True)
    # plt.savefig("Random noise.jpg")
    plt.show()

degree_3(x_train,y_train,x_test,y_test)
# Out:
# 3次多项式回归：
# 训练集均方根误差：0.277881
# 测试集均方根误差：0.275709

# %% [markdown]
# # No noise 50 samples

# %%
np.random.seed(0)
x_train = np.linspace(0, 1, 50)
y_train = np.sin(2 * np.pi * x_train)

x_test = np.linspace(0.7, 1.0, 10)
y_test = np.sin(2 * np.pi * x_test)

x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

degree_3(x_train,y_train,x_test,y_test)
# Out:
# 3次多项式回归：
# 训练集均方根误差：0.005110
# 测试集均方根误差：0.006159

# %% [markdown]
# # Outliers（野值） 50 samples

# %%
np.random.seed(0)
a_train = np.random.random((1, 50)) - 0.5
x_train = np.linspace(0, 1, 50)
y_train = np.sin(2 * np.pi * x_train)
y_train = y_train - a_train * 2
y_train = y_train[0]
x_outliers=[0.2,0.3,0.4,0.6,0.7,0.8]
y_outliers=[-2,-2.5,-3,2,2.5,3]
x_train=np.append(x_train,x_outliers)
y_train=np.append(y_train,y_outliers)

a_test = np.random.random((1, 10)) - 0.5
x_test = np.linspace(0.7, 1.0, 10)
y_test = np.sin(2 * np.pi * x_test)
y_test = y_test - a_test * 2
y_test = y_test[0]

x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

degree_3(x_train,y_train,x_test,y_test)
# Out:
# 3次多项式回归：
# 训练集均方根误差：1.239771
# 测试集均方根误差：0.371534

# %% [markdown]
# # Random noise 200 samples

# %%
np.random.seed(0)
a_train = np.random.random((1, 200)) - 0.5
x_train = np.linspace(0, 1, 200)
y_train = np.sin(2 * np.pi * x_train)
y_train = y_train - a_train * 2
y_train = y_train[0]

a_test = np.random.random((1, 10)) - 0.5
x_test = np.linspace(0.7, 1.0, 10)
y_test = np.sin(2 * np.pi * x_test)
y_test = y_test - a_test * 2
y_test = y_test[0]

x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

degree_3(x_train,y_train,x_test,y_test)
# Out:
# 3次多项式回归：
# 训练集均方根误差：0.319934
# 测试集均方根误差：0.499097

# %% [markdown]
# # No  noise 200 samples

# %%
np.random.seed(0)
x_train = np.linspace(0, 1, 200)
y_train = np.sin(2 * np.pi * x_train)

x_test = np.linspace(0.7, 1.0, 10)
y_test = np.sin(2 * np.pi * x_test)

x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

degree_3(x_train,y_train,x_test,y_test)
# Out:
# 3次多项式回归：
# 训练集均方根误差：0.004574
# 测试集均方根误差：0.006842

# %% [markdown]
# # Outliers（野值）200 samples

# %%
np.random.seed(0)
a_train = np.random.random((1, 200)) - 0.5
x_train = np.linspace(0, 1, 200)
y_train = np.sin(2 * np.pi * x_train)
y_train = y_train - a_train * 2
y_train = y_train[0]
x_outliers=[0.2,0.3,0.4,0.6,0.7,0.8]
y_outliers=[-2,-2.5,-3,2,2.5,3]
x_train=np.append(x_train,x_outliers)
y_train=np.append(y_train,y_outliers)

a_test = np.random.random((1, 10)) - 0.5
x_test = np.linspace(0.7, 1.0, 10)
y_test = np.sin(2 * np.pi * x_test)
y_test = y_test - a_test * 2
y_test = y_test[0]

x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

degree_3(x_train,y_train,x_test,y_test)
# Out:
# 3次多项式回归：
# 训练集均方根误差：0.639859
# 测试集均方根误差：0.393164
